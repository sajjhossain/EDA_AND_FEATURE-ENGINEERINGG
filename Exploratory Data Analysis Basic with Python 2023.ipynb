# %% [markdown]
# # IMPORTS AND READING DATA

# %%
import pandas as pd
import numpy as np
#now few different visualization libraries
import matplotlib.pylab as plt
#for doing exploratory plots with our data
import seaborn as sns
#style sheet for matplotlib & seaborn style plots
plt.style.use('ggplot')

# %%
#to expand the number of columns that are shown when we display a different data frame to our notebook.

# %%
# pd.set_option ('max_columns',100)

# %% [markdown]
# # IMPORT THE DATA

# %%
df = pd.read_csv("coaster_db.csv")

# %% [markdown]
# # STEP-1 DATA UNDERSTANDING
# 1. DataFrame Shape
# 2. Head and tail
# 3. dtypes
# 4. describe

# %%
df
# Out:
#                                 coaster_name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# ...

# %%
df.shape
# Out:
# (1087, 56)

# %%
#here 1087 rows and 56 columns

# %%
#head command will show the 1st 5 rows but we can change the row number we want to see.
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model  ...  speed1  \
# ...

# %%
df.head(20)
# Out:
#                               coaster_name              Length  \
# 0                       Switchback Railway      600 ft (180 m)
# 1                        Flip Flap Railway                 NaN
# 2   Switchback Railway (Euclid Beach Park)                 NaN
# 3             Loop the Loop (Coney Island)                 NaN
# 4             Loop the Loop (Young's Pier)                 NaN
# 5                           Cannon Coaster                 NaN
# 6                            Leap-The-Dips    1,452 ft (443 m)
# 7         Figure Eight (Euclid Beach Park)                 NaN
# 8                             Drop the Dip                 NaN
# 9       Scenic Railway (Euclid Beach Park)                 NaN
# 10          Loop the Loop (Olentangy Park)                 NaN
# 11                               Aero Dips                 NaN
# 12             Backety-Back Scenic Railway                 NaN
# 13             Racer (1910 roller coaster)  4,500 ft (1,400 m)
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
#df.describe(), this function will show use some information and statistics about the neumeric data of our dataset.

# %% [markdown]
# # STEP -2 DATA PREPARATION
# ** before getting into analysis, there is need of some data cleaning

# %%
# 1st of all we need to drop any column or rows that we dont want to keep/use before we continue or we might waste times cleaning up columns that we wont end up using.

# %%
#now to clean up columns we need to create subset, then edit as I wish.
#to do this subset there is 2 ways 
#1. is run df.columns then copy all the columns name then paste in the place of columns also under 2 3rd bracket df[[.column names]].

# %%
df = df[['coaster_name',
#     'Length', 'Speed', 
    'Location', 'Status', 
#     'Opening date',
#        'Type', 
    'Manufacturer', 
#     'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 
#     'Opened',
#     'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced',
    'latitude', 'longitude',
    'Type_Main',
       'opening_date_clean',
#     'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
#     'height_value', 'height_unit', 
    'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()

# %%
# we did df= df[[........]], to update the df, 
#also we added .copy(), This makes sure the python that it is a brand new data frame not just a reference to the old one.

# %%
#The second way of removing columns is "drop" command.
#df.drop(['opening date'], axis=1), here we give axis=1 , so that it knows to drop a row but column.

# %%
df
# Out:
#                                 coaster_name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1082                 American Dreier Looping                           Other
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1084               Tron Lightcycle Power Run                           Other
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
df.shape
# Out:
# (1087, 13)

# %%
df.dtypes
# Out:
# coaster_name           object
# Location               object
# Status                 object
# Manufacturer           object
# year_introduced         int64
# latitude              float64
# longitude             float64
# Type_Main              object
# opening_date_clean     object
# speed_mph             float64
# height_ft             float64
# Inversions_clean        int64
# Gforce_clean          float64
# dtype: object

# %%
#from the dtypes we can see that "opening_date_clean" dtype is object column but we dont want it to be a object column bcz its a date.
pd. to_datetime(df['opening_date_clean'])
# Out:
# 0      1884-06-16
# 1      1895-01-01
# 2             NaT
# 3      1901-01-01
# 4      1901-01-01
#           ...
# 1082          NaT
# 1083   2022-01-01
# 1084   2016-06-16
# 1085          NaT
# 1086   2022-01-01
# Name: opening_date_clean, Length: 1087, dtype: datetime64[ns]

# %%
df['opening_date_clean'] = pd. to_datetime(df['opening_date_clean'])

# %%
#now it has become a date time column, this is a way where we can make sure that all the dtypes are correct.
#Another example to change dtype is 
# pd. to_numeric(df['year_introduced'])

# %% [markdown]
# ##HOW TO RENAME OUR COLUMNS

# %%
df = df.rename(columns={'coaster_name':'Coaster_Name'})

# %%
df.head()
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status            Manufacturer  year_introduced  latitude  longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884   40.5740   -73.9780
# 1  Removed            Lina Beecher             1895   40.5780   -73.9790
# 2   Closed                     NaN             1896   41.5800   -81.5700
# 3  Removed          Edwin Prescott             1901   40.5745   -73.9780
# 4  Removed          Edwin Prescott             1901   39.3538   -74.4342
#
#   Type_Main opening_date_clean  speed_mph  height_ft  Inversions_clean  \
# ...

# %%
#now we need to find if there is any missing valye, if yes, where they are and how often they occur.

# %%
#to identify the missing values
df.isna().sum()
# Out:
# Coaster_Name            0
# Location                0
# Status                213
# Manufacturer           59
# year_introduced         0
# latitude              275
# longitude             275
# Type_Main               0
# opening_date_clean    250
# speed_mph             150
# height_ft             916
# Inversions_clean        0
# Gforce_clean          725
# dtype: int64

# %%
#now we have to see if any data is duplicated or not. bcz if there is any duplicated data we wil not need that.
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082    False
# 1083    False
# 1084    False
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %%
# if there was any duplicated value then to find them out 
# df.loc[df.duplicated()]

# %%
#finding duplicated value using subset
df.loc[df.duplicated(subset=['Coaster_Name'])]
# Out:
#                             Coaster_Name                   Location  \
# 43                 Crystal Beach Cyclone         Crystal Beach Park
# 60                           Derby Racer               Revere Beach
# 61           Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 167        Big Thunder Mountain Railroad                      Other
# 237    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ...                                  ...                        ...
# 1063                  Lil' Devil Coaster  Six Flags Great Adventure
# 1064  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 1080                          Iron Gwazi    Busch Gardens Tampa Bay
# 1082             American Dreier Looping                      Other
# 1084           Tron Lightcycle Power Run                      Other
#
#                   Status                                       Manufacturer  \
# ...

# %%
df.loc[df.duplicated(subset=['Coaster_Name'])].head()
# Out:
#                           Coaster_Name             Location     Status  \
# 43               Crystal Beach Cyclone   Crystal Beach Park    Removed
# 60                         Derby Racer         Revere Beach    Removed
# 61         Blue Streak (Conneaut Lake)   Conneaut Lake Park     Closed
# 167      Big Thunder Mountain Railroad                Other        NaN
# 237  Thunder Run (Canada's Wonderland)  Canada's Wonderland  Operating
#
#                                           Manufacturer  year_introduced  \
# 43                                  Traver Engineering             1927
# 60                                      Fred W. Pearce             1937
# 61                                                 NaN             1938
# 167  Arrow Development (California and Florida)Dyna...             1980
# 237                                         Mack Rides             1986
#
#      latitude  longitude Type_Main opening_date_clean  speed_mph  height_ft  \
# ...

# %%
#to find out why there is duplicate value, query command need to be used.
#checking an example of duplicate.
df.query('Coaster_Name =="Crystal Beach Cyclone"')
# Out:
#              Coaster_Name            Location   Status        Manufacturer  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
#
#     year_introduced  latitude  longitude Type_Main opening_date_clean  \
# 39             1926   42.8617   -79.0598      Wood         1926-01-01
# 43             1927   42.8617   -79.0598      Wood         1926-01-01
#
#     speed_mph  height_ft  Inversions_clean  Gforce_clean
# 39       60.0        NaN                 0           4.0
# 43       60.0        NaN                 0           4.0

# %%
#with this we can see both the rows has almost identical column values, except the year introduced so, we need to remove these duplicated values.

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'year_introduced',
#        'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph',
#        'height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
#so we are going to remove these duplicates with certain number of culmns.
df.loc[df.duplicated(subset=['Coaster_Name','Location','opening_date_clean'])]
# Out:
#                             Coaster_Name                   Location  \
# 43                 Crystal Beach Cyclone         Crystal Beach Park
# 60                           Derby Racer               Revere Beach
# 61           Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 167        Big Thunder Mountain Railroad                      Other
# 237    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ...                                  ...                        ...
# 1063                  Lil' Devil Coaster  Six Flags Great Adventure
# 1064  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 1080                          Iron Gwazi    Busch Gardens Tampa Bay
# 1082             American Dreier Looping                      Other
# 1084           Tron Lightcycle Power Run                      Other
#
#                   Status                                       Manufacturer  \
# ...

# %%
df.loc[df.duplicated(subset=['Coaster_Name','Location','opening_date_clean'])]
# Out:
#                             Coaster_Name                   Location  \
# 43                 Crystal Beach Cyclone         Crystal Beach Park
# 60                           Derby Racer               Revere Beach
# 61           Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 167        Big Thunder Mountain Railroad                      Other
# 237    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ...                                  ...                        ...
# 1063                  Lil' Devil Coaster  Six Flags Great Adventure
# 1064  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 1080                          Iron Gwazi    Busch Gardens Tampa Bay
# 1082             American Dreier Looping                      Other
# 1084           Tron Lightcycle Power Run                      Other
#
#                   Status                                       Manufacturer  \
# ...

# %%
# there are 97 rows which are duplicate, now we need to inverse this to remove those duplicates.

# %%
#to inverse it 
~df.duplicated(subset=['Coaster_Name','Location','opening_date_clean'])
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1082    False
# 1083     True
# 1084    False
# 1085     True
# 1086     True
# Length: 1087, dtype: bool

# %%
df.loc[~df.duplicated(subset=['Coaster_Name','Location','opening_date_clean'])]
# Out:
#                                 Coaster_Name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1079            Ice Breaker (roller coaster)                SeaWorld Orlando
# 1081                   Leviathan (Sea World)                       Sea World
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
#this will drop rows to show only non duplicated values

# %%
df.loc[~df.duplicated(subset=['Coaster_Name','Location','opening_date_clean'])]
# Out:
#                                 Coaster_Name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1079            Ice Breaker (roller coaster)                SeaWorld Orlando
# 1081                   Leviathan (Sea World)                       Sea World
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
#now we will have to reset index, to reset index
df.loc[~df.duplicated(subset=['Coaster_Name','Location','opening_date_clean'])] \
    .reset_index()
# Out:
#      index                            Coaster_Name  \
# 0        0                      Switchback Railway
# 1        1                       Flip Flap Railway
# 2        2  Switchback Railway (Euclid Beach Park)
# 3        3            Loop the Loop (Coney Island)
# 4        4            Loop the Loop (Young's Pier)
# ..     ...                                     ...
# 985   1079            Ice Breaker (roller coaster)
# 986   1081                   Leviathan (Sea World)
# 987   1083               Pantheon (roller coaster)
# 988   1085                                 Tumbili
# 989   1086          Wonder Woman Flight of Courage
#
#                            Location              Status  \
# 0                      Coney Island             Removed
# 1                     Sea Lion Park             Removed
# 2    Cleveland, Ohio, United States              Closed
# 3                             Other             Removed
# 4                             Other             Removed
# ...

# %%
df.loc[~df.duplicated(subset=['Coaster_Name','Location','opening_date_clean'])] \
    .reset_index(drop=True)
# Out:
#                                Coaster_Name                        Location  \
# 0                        Switchback Railway                    Coney Island
# 1                         Flip Flap Railway                   Sea Lion Park
# 2    Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3              Loop the Loop (Coney Island)                           Other
# 4              Loop the Loop (Young's Pier)                           Other
# ..                                      ...                             ...
# 985            Ice Breaker (roller coaster)                SeaWorld Orlando
# 986                   Leviathan (Sea World)                       Sea World
# 987               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 988                                 Tumbili                  Kings Dominion
# 989          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
#to make this updated data set as our main data set
df = df.loc[~df.duplicated(subset=['Coaster_Name','Location','opening_date_clean'])] \
    .reset_index(drop=True).copy()

# %%
df.shape
# Out:
# (990, 13)

# %% [markdown]
# #CLEANING, and understanding the data set is done.

# %% [markdown]
# # STEP 3 = Feature Understanding(this will help to look each feture individually)
# (Univariable Analysis)
#  1. Ploting Feature distribution
#  2. Histogram
#  3. KDE
#  4. Boxplot

# %%
df['year_introduced'].value_counts()
# Out:
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
#         ..
# 1956     1
# 1959     1
# 1961     1
# 1895     1
# 1884     1
# Name: year_introduced, Length: 101, dtype: int64

# %%
ax = df['year_introduced'].value_counts() \
    .head(20) \
    .plot(kind='bar', title="Top 20 Years Coaster Introduced")
ax.set_xlabel("year_introduced")
ax.set_ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
ax= df['speed_mph'].plot(kind='hist', bins = 20, title="Coaster Speed(mph)")

ax.set_xlabel("Speed(mph)")
# Out:
# Text(0.5, 0, 'Speed(mph)')

# %%
ax= df['speed_mph'].plot(kind='kde', title="Coaster Speed(mph)")

ax.set_xlabel("Speed(mph)")
# Out:
# Text(0.5, 0, 'Speed(mph)')

# %% [markdown]
# # STEP 4 = FEATURE RLATIONSHIPS (this will help us to understand how the different features relate to each other)
# 1. Scatterplot
# 2. Heatmap correlation
# 3. Pairplot
# 4. Groupby Comparisons

# %%
df.plot(kind='scatter',
        x="speed_mph",
       y="height_ft",
       title="Coaster Speed vs Height")
plt.show()

# %%
#This is creating matplotlib object when we run the plot command in pandas, to make it little bit cleaner use "plt.show()"

# %% [markdown]
# ##By using another package like seaborn we can do a littlebit more advanced analysis and plots with this data.

# %%
sns.scatterplot(x="speed_mph",
       y="height_ft",
                hue ="year_introduced",
               data= df)
# Out:
# <Axes: xlabel='speed_mph', ylabel='height_ft'>

# %% [markdown]
# ## so far we have seen relation between two features what if we need to relation between more than two features.
#
# in this case seaborn has a built in functionality called pairplot where we can compare multiple features against each other.

# %%
df.head()
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status            Manufacturer  year_introduced  latitude  longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884   40.5740   -73.9780
# 1  Removed            Lina Beecher             1895   40.5780   -73.9790
# 2   Closed                     NaN             1896   41.5800   -81.5700
# 3  Removed          Edwin Prescott             1901   40.5745   -73.9780
# 4  Removed          Edwin Prescott             1901   39.3538   -74.4342
#
#   Type_Main opening_date_clean  speed_mph  height_ft  Inversions_clean  \
# ...

# %%
sns.pairplot(df, vars= ['year_introduced', 'speed_mph', 'height_ft', 'Inversions_clean', 'Gforce_clean'],)
plt.show()

# %%
# to use diffenet colour for better understanding which coaster are made by which material we need to little change just like below

# %%
sns.pairplot(df, vars= ['year_introduced', 'speed_mph', 'height_ft', 'Inversions_clean', 'Gforce_clean'], hue = 'Type_Main')
plt.show()

# %%
# correlation between different features

# %%
df_corr= df[['year_introduced', 'speed_mph', 'height_ft', 'Inversions_clean', 'Gforce_clean']].dropna().corr()

# %%
df_corr
# Out:
#                   year_introduced  speed_mph  height_ft  Inversions_clean  \
# year_introduced          1.000000   0.171978   0.135413         -0.209887
# speed_mph                0.171978   1.000000   0.733999         -0.028705
# height_ft                0.135413   0.733999   1.000000         -0.079736
# Inversions_clean        -0.209887  -0.028705  -0.079736          1.000000
# Gforce_clean             0.160247   0.607383   0.466482          0.275991
#
#                   Gforce_clean
# year_introduced       0.160247
# speed_mph             0.607383
# height_ft             0.466482
# Inversions_clean      0.275991
# Gforce_clean          1.000000

# %%
#just another way to see this is given below
sns.heatmap(df_corr, annot=True)
plt.show()

# %% [markdown]
# # STEP 5 = ASK A QUESTION ABOUT THE DATA SET.
# try to answer a que you have using plot or statisric.

# %%
#sample questions
#1. what are the locations with the fastest roller coasters( minimum of 10 coaster at each locations)?
df.query('Location != "Other"')
# Out:
#                                Coaster_Name                        Location  \
# 0                        Switchback Railway                    Coney Island
# 1                         Flip Flap Railway                   Sea Lion Park
# 2    Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 5                            Cannon Coaster                    Coney Island
# 6                             Leap-The-Dips                   Lakemont Park
# ..                                      ...                             ...
# 985            Ice Breaker (roller coaster)                SeaWorld Orlando
# 986                   Leviathan (Sea World)                       Sea World
# 987               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 988                                 Tumbili                  Kings Dominion
# 989          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
ax = df.query('Location != "Other"') \
    .groupby('Location')['speed_mph'] \
    .agg(['mean','count']) \
    .query('count >=10') \
    .sort_values('mean')['mean'] \
    .plot(kind = 'barh', figsize=(12,5), title='Average Coast Speed by Location')

ax.set_xlabel('Average Coaster Speed')
plt.show()
